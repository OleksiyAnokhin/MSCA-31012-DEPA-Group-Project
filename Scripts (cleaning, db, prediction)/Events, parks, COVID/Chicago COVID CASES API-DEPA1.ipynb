# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/chrisreimann/Desktop/U Chicago/MSCA 31012 - Data Platforms/Final Project'

# %% [markdown]
# ### City COVID API

# %%
data=requests.get('https://data.cityofchicago.org/resource/yhhz-zm2v.json',auth=('3cxz7bqz38hha10zeshhy8r7g','4c1dfl7m5fer23lmg0kvqkgwttgw06ekhmw54gdothw3os5hxb'))

# %%
data2 = json.loads(data.content.decode())

# %%
type(data2)
# Out:
# list

# %%
print(data2)
# Out:
# [{'zip_code': 'Unknown', 'week_number': '10', 'week_start': '2020-03-01T00:00:00.000', 'week_end': '2020-03-07T00:00:00.000', 'tests_weekly': '62', 'tests_cumulative': '62', 'test_rate_weekly': '0.0', 'test_rate_cumulative': '0.0', 'deaths_weekly': '0', 'deaths_cumulative': '0', 'death_rate_weekly': '0.0', 'death_rate_cumulative': '0.0', 'population': '0', 'row_id': 'Unknown-10'}, {'zip_code': '60633', 'week_number': '11', 'week_start': '2020-03-08T00:00:00.000', 'week_end': '2020-03-14T00:00:00.000', 'tests_weekly': '0', 'tests_cumulative': '0', 'test_rate_weekly': '0.0', 'test_rate_cumulative': '0.0', 'deaths_weekly': '0', ':@computed_region_rpca_8um6': '26', 'deaths_cumulative': '0', ':@computed_region_vrxf_vc4k': '52', 'death_rate_weekly': '0.0', ':@computed_region_6mkv_f3dw': '22250', 'death_rate_cumulative': '0.0', 'population': '12871', ':@computed_region_bdys_3d7i': '586', 'row_id': '60633-11', ':@computed_region_43wa_7qmu': '47', 'zip_code_location': {'type': 'Point', 'coord
# ...

# %%
data3=pd.DataFrame(data2)

# %%
data3
# Out:
#     zip_code week_number               week_start                 week_end  \
# 0    Unknown          10  2020-03-01T00:00:00.000  2020-03-07T00:00:00.000
# 1      60633          11  2020-03-08T00:00:00.000  2020-03-14T00:00:00.000
# 2      60643          10  2020-03-01T00:00:00.000  2020-03-07T00:00:00.000
# 3      60660          10  2020-03-01T00:00:00.000  2020-03-07T00:00:00.000
# 4      60666          21  2020-05-17T00:00:00.000  2020-05-23T00:00:00.000
# ..       ...         ...                      ...                      ...
# 835    60633          16  2020-04-12T00:00:00.000  2020-04-18T00:00:00.000
# 836    60626          10  2020-03-01T00:00:00.000  2020-03-07T00:00:00.000
# 837    60654          18  2020-04-26T00:00:00.000  2020-05-02T00:00:00.000
# 838    60616          18  2020-04-26T00:00:00.000  2020-05-02T00:00:00.000
# 839    60607          12  2020-03-15T00:00:00.000  2020-03-21T00:00:00.000
#
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
data3.loc[1]
# Out:
# zip_code                                                                          60633
# week_number                                                                          11
# week_start                                                      2020-03-08T00:00:00.000
# week_end                                                        2020-03-14T00:00:00.000
# tests_weekly                                                                          0
# tests_cumulative                                                                      0
# test_rate_weekly                                                                    0.0
# test_rate_cumulative                                                                0.0
# deaths_weekly                                                                         0
# deaths_cumulative                                                                     0
# death_rate_weekly                                                                   0.0
# ...
