# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/chrisreimann/Desktop/Final Project FINAL'

# %% [markdown]
# ### Chicago Park Locations API

# %%
data=requests.get('https://data.cityofchicago.org/resource/wwy2-k7b3.json?$limit=50000',auth=('3cxz7bqz38hha10zeshhy8r7g','4c1dfl7m5fer23lmg0kvqkgwttgw06ekhmw54gdothw3os5hxb'))

# %%
data2 = json.loads(data.content.decode())

# %%
type(data2)
# Out:
# list

# %%
data3=pd.DataFrame(data2)

# %%
data3
# Out:
#     park_number         park_name           street_address    zip  acres ward  \
# 0          1162   MCKEON (JOSEPH)            600 W 36TH ST  60609    0.4   11
# 1          1139              OHIO           4712 W OHIO ST  60644   0.42   37
# 2           206    ALTGELD (JOHN)      515 S WASHTENAW AVE  60612   4.32   27
# 3           468      PARK NO. 468           4556 W 56TH ST  60629   1.32   13
# 4            33   RAINEY (EDWARD)           4350 W 79TH ST  60652  18.31   13
# ..          ...               ...                      ...    ...    ...  ...
# 576        1284          MULBERRY       3150 S ROBINSON CT  60608   0.56   11
# 577         405   DEBOW (RUSSELL)           1126 E 80TH ST  60619   0.55    8
# 578         355          NINEBARK  1447-1453 S HARDING AVE  60623   0.22   24
# 579        1155  SINTIC (GREGORY)        2835 S WALLACE ST  60616   0.14   11
# 580         178  HURLEY (TIMOTHY)          1901 W 100TH ST  60643   1.21   19
#
# ...

# %% [markdown]
# ### Write to csv for upload to GCP

# %%
data3.to_csv('park_locations.csv',index=False)
